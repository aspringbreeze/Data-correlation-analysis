# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("example_dataset.csv")

# %%
df.describe()
# Out:
#         feature_1   feature_2   feature_3   feature_4   feature_5
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.462233    0.485629    0.515648    0.530755    0.544478
# std      0.289222    0.297214    0.270272    0.303912    0.280322
# min      0.020271    0.009384    0.030734    0.021952    0.000644
# 25%      0.211930    0.243981    0.282738    0.259156    0.319069
# 50%      0.423480    0.472487    0.510382    0.545067    0.544795
# 75%      0.706389    0.750161    0.703782    0.783406    0.801858
# max      0.985158    0.989009    0.989011    0.995280    0.993914

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature_1  100 non-null    float64
#  1   feature_2  100 non-null    float64
#  2   feature_3  100 non-null    float64
#  3   feature_4  100 non-null    float64
#  4   feature_5  100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.0 KB

# %%
df.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5
# 0   0.978827   0.269072   0.428748   0.610744   0.305823
# 1   0.516343   0.242067   0.749536   0.066392   0.749588
# 2   0.419780   0.294532   0.495886   0.623970   0.220129
# 3   0.696939   0.712466   0.604261   0.515039   0.365214
# 4   0.844730   0.153239   0.740513   0.906168   0.393810

# %%
df_no_duplicates = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature_1  100 non-null    float64
#  1   feature_2  100 non-null    float64
#  2   feature_3  100 non-null    float64
#  3   feature_4  100 non-null    float64
#  4   feature_5  100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.0 KB

# %%
corr_matrix = df.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
# Conclusion: Didn't find obvious relationships between any of the columns.

# %%
sns.pairplot(df, kind='reg', plot_kws={'line_kws':{'color':'red'}})
plt.show()

# %%
sns.pairplot?

# %%
sns.pairplot(df, kind='scatter')
plt.show()
